# %%
import numpy as np
import pandas as pd

# %%
path = "/content/drive/MyDrive/mulcam_bigdata/3조 : 최종 프로젝트/김선규/data/추가데이터.csv"

# %%
pd.read_csv(path)
# Out:
#        Unnamed: 0           파일이름 질병_카테고리     질병  부서  의도  단어수         폴더명  \
# 0               0  HC-A-01995967   순환기질환    고혈압  내과  검진  162    고혈압 - 검진
# 1               1  HC-A-01995979   순환기질환    고혈압  내과  검진   92    고혈압 - 검진
# 2               2  HC-A-01995982   순환기질환    고혈압  내과  검진   90    고혈압 - 검진
# 3               3  HC-A-01995985   순환기질환    고혈압  내과  검진  129    고혈압 - 검진
# 4               4  HC-A-01995999   순환기질환    고혈압  내과  검진   88    고혈압 - 검진
# ...           ...            ...     ...    ...  ..  ..  ...         ...
# 50056        7561  HC-A-07104297   근골격질환  좌골신경통  외과  치료  108  좌골신경통 - 치료
# 50057        7562  HC-A-07104493   근골격질환  좌골신경통  외과  치료   87  좌골신경통 - 치료
# 50058        7563  HC-A-07109137   근골격질환  좌골신경통  외과  치료   99  좌골신경통 - 치료
# 50059        7564  HC-A-07111605   근골격질환  좌골신경통  외과  치료   72  좌골신경통 - 치료
# 50060        7565  HC-A-07113988   근골격질환  좌골신경통  외과  치료   90  좌골신경통 - 치료
#
#                                                       답변
# ...

# %%
df = pd.read_csv(path, index_col=0)
df.head(3)
# Out:
#             파일이름 질병_카테고리   질병  부서  의도  단어수       폴더명  \
# 0  HC-A-01995967   순환기질환  고혈압  내과  검진  162  고혈압 - 검진
# 1  HC-A-01995979   순환기질환  고혈압  내과  검진   92  고혈압 - 검진
# 2  HC-A-01995982   순환기질환  고혈압  내과  검진   90  고혈압 - 검진
#
#                                                   답변
# 0  고혈압 환자의 기본 검진은 최초의 진단과 동시에 시작되어야 합니다. 만약 고혈압이 ...
# 1  고혈압의 검진은 정확한 검사와 주기적인 모니터링이 필요한 치료 과정입니다. 고혈압으...
# 2  고혈압이 확인되면, 의사는 환자에게 정기적으로 혈압을 측정하고 결과를 확인하는 것이...

# %%
df.의도.unique()
# Out:
# array(['검진', '식이, 생활', '약물', '예방', '운동', '원인', '정의', '증상', '진단', '치료',
#        '재활'], dtype=object)

# %% [markdown]
# 어떤 의도를 사용할가 = 어떤 서비스를 제공할가
