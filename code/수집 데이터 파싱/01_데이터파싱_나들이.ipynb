# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '/content/drive/MyDrive/mulcam_bigdata/3조 : 최종 프로젝트/김건우/data/문화 빅데이터 플렛폼/KC_ODSN_WALK_RECOMEND_LIST_2023.csv'

# %%
pd.read_csv(path)
# Out:
#                   ESNTL_ID LCLAS_NM   MLSFC_NM   FCLTY_NM  CTPRVN_CD  \
# 0      KCOWRPO23N000000001     쇼핑시설  쇼핑시설_전통시장     원미부흥시장         41
# 1      KCOWRPO23N000000002     쇼핑시설  쇼핑시설_전통시장     원미종합시장         41
# 2      KCOWRPO23N000000003       자연      자연_공원       원미별빛         41
# 3      KCOWRPO23N000000004       자연      자연_공원         원미         41
# 4      KCOWRPO23N000000005     쇼핑시설  쇼핑시설_전통시장       음성시장         43
# ...                    ...      ...        ...        ...        ...
# 18682  KCOWRPO23N000018683       자연      자연_공원     강하 소공원         41
# 18683  KCOWRPO23N000018684       자연      자연_공원  한강아트로드 공원         41
# 18684  KCOWRPO23N000018685       자연      자연_공원     공흥 소공원         41
# 18685  KCOWRPO23N000018686       자연      자연_공원   광탄3호 소공원         41
# 18686  KCOWRPO23N000018687       자연      자연_공원   광탄2호 소공원         41
#
#       CTPRVN_NM  SIGNGU_CD SIGNGU_NM  LEGALDONG_CD LEGALDONG_NM  ...  \
# ...

# %%
raw = pd.read_csv(path)
df = raw.copy()
df.head(3)
# Out:
#               ESNTL_ID LCLAS_NM   MLSFC_NM FCLTY_NM  CTPRVN_CD CTPRVN_NM  \
# 0  KCOWRPO23N000000001     쇼핑시설  쇼핑시설_전통시장   원미부흥시장         41       경기도
# 1  KCOWRPO23N000000002     쇼핑시설  쇼핑시설_전통시장   원미종합시장         41       경기도
# 2  KCOWRPO23N000000003       자연      자연_공원     원미별빛         41       경기도
#
#    SIGNGU_CD SIGNGU_NM  LEGALDONG_CD LEGALDONG_NM  ...  \
# 0      41190   부천시 원미구    4119010100          원미동  ...
# 1      41190   부천시 원미구    4119010100          원미동  ...
# 2      41190   부천시 원미구    4119010100          원미동  ...
#
#               BULD_MANAGE_CD TEL_NO   ZIP_NO HMPG_URL   FCLTY_LA    FCLTY_LO  \
# 0  4119510100101180000000000    0.0  14571.0      0.0  37.553516  126.921715
# 1  4119510100100970000000000    0.0  14568.0      0.0  37.545392  126.953319
# 2  4119510100101270000000000    0.0  14571.0      0.0  37.491966  126.787309
#
#   ORIGIN_NM  ADIT_DC   UPDT_DT  REGIST_DT
# 0     공공데이터      상설장  20231231   20231231
# 1     공공데이터      상설장  20231231   20231231
# ...

# %%
df.columns
# Out:
# Index(['ESNTL_ID', 'LCLAS_NM', 'MLSFC_NM', 'FCLTY_NM', 'CTPRVN_CD',
#        'CTPRVN_NM', 'SIGNGU_CD', 'SIGNGU_NM', 'LEGALDONG_CD', 'LEGALDONG_NM',
#        'ROAD_NM_CD', 'FCLTY_ROAD_NM_ADDR', 'LNM_ADDR', 'ADDR_ENG_NM',
#        'ADSTRD_CD', 'BULD_NM', 'BULD_MANAGE_CD', 'TEL_NO', 'ZIP_NO',
#        'HMPG_URL', 'FCLTY_LA', 'FCLTY_LO', 'ORIGIN_NM', 'ADIT_DC', 'UPDT_DT',
#        'REGIST_DT'],
#       dtype='object')

# %% [markdown]
# ESNTL_ID : 고유ID<br>
# LCLAS_NM : 대분류명<br>
# MLSFC_NM : 중분류명<br>
# FCLTY_NM : 시설명<br>
# CTPRVN_CD : 시도코드<br>
# CTPRVN_NM : 시도명<br>
# SIGNGU_CD : 시군구코드<br>
# SIGNGU_NM : 시군구명<br>
# LEGALDONG_CD : 법정동코드<br>
# LEGALDONG_NM : 법정동명<br>
# ROAD_NM_CD : 도로명코드<br>
# FCLTY_ROAD_NM_ADDR : 시설도로명주소<br>
# LNM_ADDR : 지번주소<br>
# ADDR_ENG_NM : 주소영문명<br>
# ADSTRD_CD : 행정동코드<br>
# BULD_NM : 건물명<br>
# BULD_MANAGE_CD : 건물관리코드<br>
# TEL_NO : 전화번호<br>
# ZIP_NO : 우편번호<br>
# HMPG_URL : 홈페이지URL<br>
# FCLTY_LA : 시설위도<br>
# FCLTY_LO : 시설경도<br>
# ORIGIN_NM : 출처명<br>
# ADIT_DC : 추가설명<br>
# UPDT_DT : 수정일시<br>
# REGIST_DT : 등록일시<br>

# %%
df.shape
# Out:
# (18687, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18687 entries, 0 to 18686
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ESNTL_ID            18687 non-null  object
#  1   LCLAS_NM            18687 non-null  object
#  2   MLSFC_NM            18687 non-null  object
#  3   FCLTY_NM            18687 non-null  object
#  4   CTPRVN_CD           18687 non-null  int64
#  5   CTPRVN_NM           18687 non-null  object
#  6   SIGNGU_CD           18687 non-null  int64
#  7   SIGNGU_NM           18625 non-null  object
#  8   LEGALDONG_CD        18687 non-null  int64
#  9   LEGALDONG_NM        18687 non-null  object
#  10  ROAD_NM_CD          18438 non-null  float64
#  11  FCLTY_ROAD_NM_ADDR  10253 non-null  object
#  12  LNM_ADDR            18687 non-null  object
#  13  ADDR_ENG_NM         7401 non-null   object
#  14  ADSTRD_CD           8655 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# ESNTL_ID                  0
# LCLAS_NM                  0
# MLSFC_NM                  0
# FCLTY_NM                  0
# CTPRVN_CD                 0
# CTPRVN_NM                 0
# SIGNGU_CD                 0
# SIGNGU_NM                62
# LEGALDONG_CD              0
# LEGALDONG_NM              0
# ROAD_NM_CD              249
# FCLTY_ROAD_NM_ADDR     8434
# LNM_ADDR                  0
# ADDR_ENG_NM           11286
# ADSTRD_CD             10032
# BULD_NM               13797
# BULD_MANAGE_CD        11286
# TEL_NO                  210
# ZIP_NO                 8791
# HMPG_URL                210
# FCLTY_LA                  0
# FCLTY_LO                  0
# ORIGIN_NM                 0
# ADIT_DC                   0
# UPDT_DT                   0
# REGIST_DT                 0
# dtype: int64

# %%
df.describe()
# Out:
#           CTPRVN_CD     SIGNGU_CD  LEGALDONG_CD    ROAD_NM_CD     ADSTRD_CD  \
# count  18687.000000  18687.000000  1.868700e+04  1.843800e+04  8.655000e+03
# mean      36.816771  37137.778777  3.701664e+09  1.851901e+11  3.748244e+09
# std       12.016228  12014.902960  1.220372e+09  2.043106e+11  1.258719e+09
# min        0.000000      0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 25%       29.000000  29155.000000  2.914013e+09  0.000000e+00  2.823711e+09
# 50%       41.000000  41550.000000  4.150011e+09  1.114041e+11  4.139010e+09
# 75%       45.000000  45113.000000  4.511312e+09  4.131044e+11  4.713032e+09
# max       52.000000  52800.000000  5.280041e+09  5.280046e+11  5.280041e+09
#
#              TEL_NO        ZIP_NO  HMPG_URL      FCLTY_LA      FCLTY_LO  \
# count  1.847700e+04   9896.000000   18477.0  18687.000000  18687.000000
# mean   2.355039e+07  30301.115198       0.0     36.436926    127.276358
# ...
