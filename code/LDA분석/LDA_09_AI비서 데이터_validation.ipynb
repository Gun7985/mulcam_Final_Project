# %%
import numpy as np
import pandas as pd

# %%
path="/content/drive/MyDrive/mulcam_bigdata/3조 : 최종 프로젝트/공용/AI명령어 데이터/명령어 음성(노인남여)/AI비서 데이터_validation.csv"

# %%
pd.read_csv(path)
# Out:
#                               대화      성별     연령대        지역    사투리 녹음환경 소음환경  \
# 0        운동으로 체조 하려는데 도와 주면 좋겠네.  Female   60~69  서울/인천/경기  경기/서울   가정   가정
# 1                    알람 그만 울려 줘.  Female   60~69  서울/인천/경기  경기/서울   가정   가정
# 2         내가 따라 할 만한 건강 체조 틀어 봐.  Female   60~69  서울/인천/경기  경기/서울   가정   가정
# 3                   나 땡벌 노래 부를게.  Female   60~69  서울/인천/경기  경기/서울   가정   가정
# 4            동네 맛집 찾아서 나한테 알려 줘.  Female   60~69  서울/인천/경기  경기/서울   가정   가정
# ...                          ...     ...     ...       ...    ...  ...  ...
# 83690   오늘 열 시 케이비에스 드라마 예약해 줄래?  Female  over70  서울/인천/경기  경기/서울   가정   가정
# 83691     뉴스 나오는 라디오로 주파수 변경해 줘.  Female  over70  서울/인천/경기  경기/서울   가정   가정
# 83692  구구단으로 내가 이기나 네가 이기나 해 보자.  Female  over70  서울/인천/경기  경기/서울   가정   가정
# 83693             끝말 이어 말하기 해 줘.  Female  over70  서울/인천/경기  경기/서울   가정   가정
# 83694          딸이랑 한 대화 전문 보여 줘.  Female  over70  서울/인천/경기  경기/서울   가정   가정
#
#                                     파일이름
# 0      n_0310-12001-02-01-BHJ-F-08-A.wav
# 1      n_0310-12002-02-01-BHJ-F-08-A.wav
# 2      n_0310-12003-02-01-BHJ-F-08-A.wav
# 3      n_0310-12004-02-01-BHJ-F-08-A.wav
# 4      n_0310-12005-02-01-BHJ-F-08-A.wav
# ...                                  ...
# 83690  n_0878-12996-02-01-KCJ-F-09-A.wav
# 83691  n_0878-12997-02-01-KCJ-F-09-A.wav
# 83692  n_0878-12998-02-01-KCJ-F-09-A.wav
# 83693  n_0878-12999-02-01-KCJ-F-09-A.wav
# 83694  n_0878-13000-02-01-KCJ-F-09-A.wav
#
# [83695 rows x 8 columns]

# %%
raw = pd.read_csv(path)
raw.head()
# Out:
#                         대화      성별    연령대        지역    사투리 녹음환경 소음환경  \
# 0  운동으로 체조 하려는데 도와 주면 좋겠네.  Female  60~69  서울/인천/경기  경기/서울   가정   가정
# 1              알람 그만 울려 줘.  Female  60~69  서울/인천/경기  경기/서울   가정   가정
# 2   내가 따라 할 만한 건강 체조 틀어 봐.  Female  60~69  서울/인천/경기  경기/서울   가정   가정
# 3             나 땡벌 노래 부를게.  Female  60~69  서울/인천/경기  경기/서울   가정   가정
# 4      동네 맛집 찾아서 나한테 알려 줘.  Female  60~69  서울/인천/경기  경기/서울   가정   가정
#
#                                 파일이름
# 0  n_0310-12001-02-01-BHJ-F-08-A.wav
# 1  n_0310-12002-02-01-BHJ-F-08-A.wav
# 2  n_0310-12003-02-01-BHJ-F-08-A.wav
# 3  n_0310-12004-02-01-BHJ-F-08-A.wav
# 4  n_0310-12005-02-01-BHJ-F-08-A.wav

# %%
df = raw.copy()
df.head()
# Out:
#                         대화      성별    연령대        지역    사투리 녹음환경 소음환경  \
# 0  운동으로 체조 하려는데 도와 주면 좋겠네.  Female  60~69  서울/인천/경기  경기/서울   가정   가정
# 1              알람 그만 울려 줘.  Female  60~69  서울/인천/경기  경기/서울   가정   가정
# 2   내가 따라 할 만한 건강 체조 틀어 봐.  Female  60~69  서울/인천/경기  경기/서울   가정   가정
# 3             나 땡벌 노래 부를게.  Female  60~69  서울/인천/경기  경기/서울   가정   가정
# 4      동네 맛집 찾아서 나한테 알려 줘.  Female  60~69  서울/인천/경기  경기/서울   가정   가정
#
#                                 파일이름
# 0  n_0310-12001-02-01-BHJ-F-08-A.wav
# 1  n_0310-12002-02-01-BHJ-F-08-A.wav
# 2  n_0310-12003-02-01-BHJ-F-08-A.wav
# 3  n_0310-12004-02-01-BHJ-F-08-A.wav
# 4  n_0310-12005-02-01-BHJ-F-08-A.wav

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83695 entries, 0 to 83694
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대화      83695 non-null  object
#  1   성별      83695 non-null  object
#  2   연령대     83695 non-null  object
#  3   지역      83695 non-null  object
#  4   사투리     83695 non-null  object
#  5   녹음환경    83695 non-null  object
#  6   소음환경    83695 non-null  object
#  7   파일이름    83695 non-null  object
# dtypes: object(8)
# memory usage: 5.1+ MB

# %% [markdown]
# #LDA 분석

# %%
# !pip install -q pandas numpy scikit-learn konlpy pyLDAvis
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 27.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 35.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 18.2 MB/s eta 0:00:00

# %%
import pandas as pd
import numpy as np
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import pyLDAvis.lda_model

# 1. 텍스트 전처리
def preprocess_text(text):
    okt = Okt()
    tokens = okt.nouns(text)  # 명사만 추출
    return ' '.join(tokens)

df['preprocessed'] = df['대화'].apply(preprocess_text)

# 2. 단어 벡터화
vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
doc_term_matrix = vectorizer.fit_transform(df['preprocessed'])

# 3. LDA 모델 학습
lda_model = LatentDirichletAllocation(n_components=5, random_state=42)
lda_output = lda_model.fit_transform(doc_term_matrix)

# %%
# 4. 결과 시각화
pyLDAvis.enable_notebook()
vis = pyLDAvis.lda_model.prepare(lda_model, doc_term_matrix, vectorizer)
pyLDAvis.display(vis)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el23431352526556392325783104937" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el23431352526556392325783104937_data = {"mdsDat": {"x": [0.300914554042985, 0.12989192303394848, -0.07514556895155007, -0.08050269307766819, -0.2751582150477154], "y": [0.08853497001470535, -0.1620319422572763, 0.29527830615993045, -0.22825409550653156, 0.006472761589171977], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [22.114958981207064, 21.254999404660403, 19.84654349440243, 19.112359338170176, 17.67113878155994]}, "tinfo": {"Term": ["\ubaa8\ub4dc", "\uc678\ucd9c", "\uc608\uc57d", "\ub0b4\uc77c", "\ube68\ub798", "\uc774\ubc88", "\uc804\ud654", "\uc54c\ub78c", "\uc6b4\uc138", "\ubc29\ubc94", "\ud2f0\ube0c\uc774", "\uc624\ub298", "\uc774\uc81c", "\ubc29\uc1a1", "\uc77c\uc815", "\uacf5\uae30", "\uba54\uc77c", "\ub274\uc2a4", "\uba54\uc2dc\uc9c0", "\uc7ac\uc0dd", "\uc790\ub9c9", "\uc601\uc0c1", "\uc124\uc815", "\ub178\ub798", "\uc2dc\uc791", "\ubc88\ud638", "\uc138\ud0c1", "\uba85\uc0c1", "\uc5b8\uc81c", "\ub561\ubc8c", "\ubc29\uc1a1", "\uc7ac\uc0dd", "\uc601\uc0c1", "\uba85\uc0c1", "\ube4c\ubcf4\ub4dc", "\uc0b0\uc218", "\ubcd1\uc6d0", "\ud2b8\ub85c\ud2b8", "\ub9e4\uc77c", "\uac80\uc0c9\uc5b4", "\ub2e4\uc12f", "\uc9c4\ub8cc", "\uc608\ub2a5", "\ud504\ub85c\uadf8\ub7a8", "\ubaa9\ub85d", "\uc120\uace1", "\uce60\uc2ed", "\uce98\ub9b0\ub354", "\uc5f4\u
c218", "\uc2dc\uc791", "\uc790\ub3d9", "\uc138\ud0c1\uae30", "\uc804\ud654\ubc88\ud638\ubd80", "\ubc29\uae08", "\uccb4\uc870", "\uc815\ub3c4", "\uc2dc\uac04", "\uc0c1\ud0dc", "\ud655\uc778", "\ub85c\ub610", "\uc5e0\ube44\uc528", "\uc9c0\uae08", "\uc5b4\uc81c", "\ubd80\ud0c1", "\ub4dc\ub77c\ub9c8", "\ub2e4\uc2dc", "\ubc88\ud638", "\uc774\ubc88", "\uc6b4\uc138", "\ub561\ubc8c", "\uc5b8\uc81c", "\ubcf4\uc77c\ub7ec", "\uae34\uae09", "\uc990\uaca8\ucc3e\uae30", "\ucd94\uac00", "\uae30\uc628", "\uc5f0\ub77d", "\uac8c\uc790\ub9ac", "\ud398\uc774\uc9c0", "\ud0dc\ud48d", "\uc77c\uc77c\uad6c", "\uc18c\uc2dd", "\ub4f1\ub85d", "\ud6a8\uacfc", "\u ...

# %%
# 5. 토픽별 주요 단어 출력
def print_topics(model, vectorizer, top_n=10):
    for idx, topic in enumerate(model.components_):
        print(f"Topic {idx + 1}:")
        print([(vectorizer.get_feature_names_out()[i], topic[i])
                for i in topic.argsort()[:-top_n - 1:-1]])

print_topics(lda_model, vectorizer)
# Out:
# Topic 1:
# [('모드', 3611.1909192759185), ('외출', 2978.7254515427862), ('전화', 1944.198603725376), ('방범', 1600.1993096636197), ('지금', 1421.540019819687), ('자막', 1328.5044340683726), ('공기', 1318.1997084680147), ('청정기', 823.199961648456), ('상황', 666.1977354333882), ('에어컨', 588.1866875049432)]
# Topic 2:
# [('내일', 2892.500168836541), ('알람', 2523.31364319787), ('뉴스', 2279.776012913086), ('오늘', 1867.9144271781465), ('이제', 1744.1942839311173), ('예약', 1564.674607632437), ('날씨', 1259.846244541399), ('지금', 1254.0550850981951), ('경기', 1104.1797106142667), ('설법', 1077.6178738341)]
# Topic 3:
# [('이번', 2115.1973916991496), ('오늘', 2004.472444252742), ('메시지', 1817.9617002644216), ('운세', 1775.1988872940565), ('일정', 1478.3246898039556), ('번호', 1285.8839502537933), ('지금', 1193.4762439707636), ('언제', 1092.1668781663834), ('땡벌', 1075.197199570554), ('확인', 1037.6029224476474)]
# Topic 4:
# [('예약', 3624.7087333948416), ('방송', 1677.1955877928158), ('설정', 1672.1844122771224), ('노래', 1591.5767829101046), ('재생', 1497.1980861849688), ('영상', 1410.1971051640273), ('명상', 1246.1988536580702), ('부탁', 1127.4144777370439), ('경기', 1065.8605600213602), ('빌보드', 925.198406249857)]
# Topic 5:
# [('빨래', 2270.079589982645), ('티브이', 1758.1962078039805), ('메일', 1416.1987514290752), ('시간', 1397.286983950207), ('시작', 1339.2529496381042), ('확인', 1326.3541850880245), ('자동', 1236.9893823029663), ('세탁', 1163.198503722734), ('체조', 1091.3708242707394), ('회전', 1090.199671011169)]
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# #중복 제거 값 LDA 분석

# %%
# 중복 제거
df_clean = df.drop_duplicates(subset=["대화"])
df_clean.reset_index(drop=True, inplace=True)
df_clean.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                         대화      성별    연령대        지역    사투리 녹음환경 소음환경  \
# 0  운동으로 체조 하려는데 도와 주면 좋겠네.  Female  60~69  서울/인천/경기  경기/서울   가정   가정
# 1              알람 그만 울려 줘.  Female  60~69  서울/인천/경기  경기/서울   가정   가정
# 2   내가 따라 할 만한 건강 체조 틀어 봐.  Female  60~69  서울/인천/경기  경기/서울   가정   가정
# 3             나 땡벌 노래 부를게.  Female  60~69  서울/인천/경기  경기/서울   가정   가정
# 4      동네 맛집 찾아서 나한테 알려 줘.  Female  60~69  서울/인천/경기  경기/서울   가정   가정
#
#                                 파일이름 preprocessed
# 0  n_0310-12001-02-01-BHJ-F-08-A.wav      운동 체조 도
# 1  n_0310-12002-02-01-BHJ-F-08-A.wav           알람
# 2  n_0310-12003-02-01-BHJ-F-08-A.wav    내 만 건강 체조
# 3  n_0310-12004-02-01-BHJ-F-08-A.wav      나 땡벌 노래
# 4  n_0310-12005-02-01-BHJ-F-08-A.wav      동네 맛집 나

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2157 entries, 0 to 2156
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   대화            2157 non-null   object
#  1   성별            2157 non-null   object
#  2   연령대           2157 non-null   object
#  3   지역            2157 non-null   object
#  4   사투리           2157 non-null   object
#  5   녹음환경          2157 non-null   object
#  6   소음환경          2157 non-null   object
#  7   파일이름          2157 non-null   object
#  8   preprocessed  2157 non-null   object
# dtypes: object(9)
# memory usage: 151.8+ KB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pandas as pd
import numpy as np
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import pyLDAvis
import pyLDAvis.lda_model

# 1. 텍스트 전처리
def preprocess_text(text):
    if pd.isna(text):
        return ""
    okt = Okt()
    tokens = okt.nouns(str(text))  # 문자열로 변환
    return ' '.join(tokens)

# NaN 값 확인
print("전처리 전 NaN 값의 수:", df_clean['대화'].isna().sum())

# 전처리 적용
df_clean['preprocessed'] = df_clean['대화'].apply(preprocess_text)

# 전처리 후 빈 문자열 확인
print("전처리 후 빈 문자열의 수:", (df_clean['preprocessed'] == '').sum())

# 빈 문자열 제거
df_clean = df_clean[df_clean['preprocessed'] != '']

# 2. 단어 벡터화
vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
doc_term_matrix = vectorizer.fit_transform(df_clean['preprocessed'])

# 3. LDA 모델 학습
lda_model = LatentDirichletAllocation(n_components=5, random_state=42)
lda_output = lda_model.fit_transform(doc_term_matrix)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 전처리 전 NaN 값의 수: 0
# <ipython-input-13-3bd4136b0f94>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['preprocessed'] = df_clean['대화'].apply(preprocess_text)
# 전처리 후 빈 문자열의 수: 1

# %%
# 4. 결과 시각화
pyLDAvis.enable_notebook()
vis = pyLDAvis.lda_model.prepare(lda_model, doc_term_matrix, vectorizer)
pyLDAvis.display(vis)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el23431352526556422568917458595" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el23431352526556422568917458595_data = {"mdsDat": {"x": [0.14656073850026916, -0.09463737263222208, 0.22719082841170424, -0.22926909454739408, -0.049845099732357304], "y": [0.14993759822533756, -0.2875629522184586, -0.07098775349700932, 0.1263100832202001, 0.08230302426993029], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [21.541733293561744, 21.056161904930164, 20.312684646750412, 20.308776409174794, 16.780643745582886]}, "tinfo": {"Term": ["\ubaa8\ub4dc", "\uc624\ub298", "\uc54c\ub78c", "\ub0b4\uc77c", "\uc678\ucd9c", "\uc2dc\uac04", "\uc9c0\uae08", "\uba54\uc2dc\uc9c0", "\ub274\uc2a4", "\uc804\ud654", "\uc608\uc57d", "\uc124\uc815", "\ubc88\ud638", "\ud2f0\ube44", "\ub85c\ub610", "\ubd80\ud0c1", "\uc774\uc81c", "\uacbd\uae30", "\ubc29\ubc94", "\ube68\ub798", "\ub178\ub798", "\uba54\uc77c", "\ub2e4\uc74c", "\uc774\ubc88", "\ubb38\uc81c", "\ub0a0\uc528", "\uc77c\uc815
c\uac8c", "\uc77c\uc77c\uc0ac", "\ub204\uad6c", "\ub3d9\ub124", "\uc21c\uc704", "\uc0ac\ub78c", "\uc790\ub9c9", "\uac80\uc0c9", "\ubb38\uc790", "\uc57d\uc18d", "\ud1b5\ud654", "\uc608\uc57d", "\uc790\ub3d9", "\ub2e4\uc12f", "\ubbf8\ub9ac", "\uc800\ub141", "\uc2dc\uac04", "\ud2f0\ube44", "\uacf5\uae30", "\uba85\uc0c1", "\uc815\ub3c4", "\uba3c\uc9c0", "\ubbf8\uc138", "\uccad\uc815\uae30", "\ub2e8\uacc4", "\uc5bc\ub9c8\ub098", "\ud2b8\ub85c\ud2b8", "\uc5bc\ub9c8", "\ub9db\uc9d1", "\ub760\ubcc4", "\ub18d\ub3c4", "\ub204\uac00", "\uae30\ub2a5", "\ud0dc\ud48d", "\uac8c\uc790\ub9ac", "\uac74\uc870", "\ud5f9\uad7c", "\ud074\ub9b0", "\ud558\ub2c8", "\uce60\uc2ed", "\ub0a8\uc790", "\ubc30\uad6c", "\uc774\uae30", "\ub144\ub300", "\ub9d0\ub3d9\ubb34", "\uc740\ud589", "\uc138\ud0c1\uae30", "\uc138\ud0c1", "\ube4c\ubcf4\ub4dc", "\ub178\ub798", "\uc778\uae30", "\uc601\uc0c1", "\ub561\ubc8c", "\uc6b4\uc138", "\uc790\ub3d9", "\ucd94\ucc9c", "\uad6c\uad6c\ub2e8", "\uc9c0\uae08", "\ube68\ub798", "\uc804\uc6d0", "\uc774\ubc88", "\u ...

# %%
# 5. 토픽별 주요 단어 출력
def print_topics(model, vectorizer, top_n=10):
    feature_names = vectorizer.get_feature_names_out()
    for idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[:-top_n - 1:-1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]
        print(f"Topic {idx + 1}:")
        for feat, weight in zip(top_features, weights):
            print(f"{feat}: {weight:.4f}")
        print()

print_topics(lda_model, vectorizer)
# Out:
# Topic 1:
# 오늘: 103.1215
# 알람: 87.1966
# 내일: 81.1974
# 예약: 69.0375
# 부탁: 65.3047
# 설정: 57.6482
# 경기: 50.8519
# 날씨: 32.1978
# 시청: 25.1961
# 축구: 23.1973
#
# Topic 2:
# 시간: 76.1952
# 티비: 47.1974
# 노래: 46.5320
# 지금: 44.7090
# 공기: 29.1992
# 운세: 28.1934
# 자동: 26.4191
# 세탁: 26.2345
# 명상: 25.1978
# 빌보드: 25.0434
#
# Topic 3:
# 예약: 44.2590
# 빨래: 35.9396
# 이번: 33.7117
# 일정: 27.6957
# 체조: 26.2121
# 재생: 25.4207
# 언제: 25.1975
# 건강: 23.1997
# 확인: 23.0672
# 회전: 22.1993
#
# Topic 4:
# 모드: 91.1979
# 지금: 84.6869
# 외출: 80.1995
# 뉴스: 70.2537
# 이제: 44.1968
# 방범: 43.1994
# 채널: 26.2468
# 방송: 23.8292
# 설법: 23.2440
# 보일러: 21.1993
#
# Topic 5:
# 메시지: 65.1409
# 전화: 56.1971
# 번호: 49.1975
# 로또: 45.1908
# 메일: 40.1966
# 다음: 40.1939
# 문제: 32.1978
# 예약: 26.3030
# 자막: 26.2253
# 산수: 26.1987
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
