# %%
import numpy as np
import pandas as pd

# %%
path="/content/drive/MyDrive/mulcam_bigdata/3조 : 최종 프로젝트/공용/AI명령어 데이터/명령어 음성(노인남여)/AI로봇 데이터_50대_validation.csv"

# %%
pd.read_csv(path)
# Out:
#                                        대화      성별    연령대        지역    사투리  \
# 0                   나 열 시에는 체크인할 수 있는 거야?    Male  20~29  서울/인천/경기  경기/서울
# 1                             이거 어떻게 퇴실해?    Male  20~29  서울/인천/경기  경기/서울
# 2                      주차 요금 나온 거 다 보여 줘.    Male  20~29  서울/인천/경기  경기/서울
# 3                            주차비를 결제해 주지.    Male  20~29  서울/인천/경기  경기/서울
# 4                          아무나 간병인 불러 줄래?    Male  20~29  서울/인천/경기  경기/서울
# ...                                   ...     ...    ...       ...    ...
# 135692               숙소 직원이 직접 와야 할 것 같아.  Female  50~59  서울/인천/경기  경기/서울
# 135693                     시간당 주차비 안내해 줘.  Female  50~59  서울/인천/경기  경기/서울
# 135694  삼십 일에 독감 예방주사 맞게 신생아과 미리 예약 잡아 줘.  Female  50~59  서울/인천/경기  경기/서울
# 135695    여기서 서울역까지 가는데 대중교통 배차 시간 어떻게 돼?  Female  50~59  서울/인천/경기  경기/서울
# 135696                    주차 값 카드로 정산해 줘.  Female  50~59  서울/인천/경기  경기/서울
#
#        녹음환경 소음환경                              파일이름
# 0       사무실  사무실  CE0271-1001-01-02-LTM-M-04-A.wav
# 1       사무실  사무실  CE0271-1002-01-02-LTM-M-04-A.wav
# 2       사무실  사무실  CE0271-1003-01-02-LTM-M-04-A.wav
# 3       사무실  사무실  CE0271-1004-01-02-LTM-M-04-A.wav
# 4       사무실  사무실  CE0271-1005-01-02-LTM-M-04-A.wav
# ...     ...  ...                               ...
# 135692   가정   가정  e_0355-4996-01-02-LJL-F-07-A.wav
# 135693   가정   가정  e_0355-4997-01-02-LJL-F-07-A.wav
# 135694   가정   가정  e_0355-4998-01-02-LJL-F-07-A.wav
# 135695   가정   가정  e_0355-4999-01-02-LJL-F-07-A.wav
# 135696   가정   가정  e_0355-5000-01-02-LJL-F-07-A.wav
#
# [135697 rows x 8 columns]

# %%
raw = pd.read_csv(path)
raw.head()
# Out:
#                       대화    성별    연령대        지역    사투리 녹음환경 소음환경  \
# 0  나 열 시에는 체크인할 수 있는 거야?  Male  20~29  서울/인천/경기  경기/서울  사무실  사무실
# 1            이거 어떻게 퇴실해?  Male  20~29  서울/인천/경기  경기/서울  사무실  사무실
# 2     주차 요금 나온 거 다 보여 줘.  Male  20~29  서울/인천/경기  경기/서울  사무실  사무실
# 3           주차비를 결제해 주지.  Male  20~29  서울/인천/경기  경기/서울  사무실  사무실
# 4         아무나 간병인 불러 줄래?  Male  20~29  서울/인천/경기  경기/서울  사무실  사무실
#
#                                파일이름
# 0  CE0271-1001-01-02-LTM-M-04-A.wav
# 1  CE0271-1002-01-02-LTM-M-04-A.wav
# 2  CE0271-1003-01-02-LTM-M-04-A.wav
# 3  CE0271-1004-01-02-LTM-M-04-A.wav
# 4  CE0271-1005-01-02-LTM-M-04-A.wav

# %%
df = raw.copy()
df.head()
# Out:
#                       대화    성별    연령대        지역    사투리 녹음환경 소음환경  \
# 0  나 열 시에는 체크인할 수 있는 거야?  Male  20~29  서울/인천/경기  경기/서울  사무실  사무실
# 1            이거 어떻게 퇴실해?  Male  20~29  서울/인천/경기  경기/서울  사무실  사무실
# 2     주차 요금 나온 거 다 보여 줘.  Male  20~29  서울/인천/경기  경기/서울  사무실  사무실
# 3           주차비를 결제해 주지.  Male  20~29  서울/인천/경기  경기/서울  사무실  사무실
# 4         아무나 간병인 불러 줄래?  Male  20~29  서울/인천/경기  경기/서울  사무실  사무실
#
#                                파일이름
# 0  CE0271-1001-01-02-LTM-M-04-A.wav
# 1  CE0271-1002-01-02-LTM-M-04-A.wav
# 2  CE0271-1003-01-02-LTM-M-04-A.wav
# 3  CE0271-1004-01-02-LTM-M-04-A.wav
# 4  CE0271-1005-01-02-LTM-M-04-A.wav

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135697 entries, 0 to 135696
# Data columns (total 8 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   대화      135697 non-null  object
#  1   성별      135697 non-null  object
#  2   연령대     135697 non-null  object
#  3   지역      135697 non-null  object
#  4   사투리     135697 non-null  object
#  5   녹음환경    135697 non-null  object
#  6   소음환경    135697 non-null  object
#  7   파일이름    135697 non-null  object
# dtypes: object(8)
# memory usage: 8.3+ MB

# %% [markdown]
# #LDA 분석

# %%
# !pip install -q pandas numpy scikit-learn konlpy pyLDAvis
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 89.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 86.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 36.6 MB/s eta 0:00:00

# %%
import pandas as pd
import numpy as np
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import pyLDAvis.lda_model

# 1. 텍스트 전처리
def preprocess_text(text):
    okt = Okt()
    tokens = okt.nouns(text)  # 명사만 추출
    return ' '.join(tokens)

df['preprocessed'] = df['대화'].apply(preprocess_text)

# 2. 단어 벡터화
vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
doc_term_matrix = vectorizer.fit_transform(df['preprocessed'])

# 3. LDA 모델 학습
lda_model = LatentDirichletAllocation(n_components=5, random_state=42)
lda_output = lda_model.fit_transform(doc_term_matrix)

# %%
# 4. 결과 시각화
pyLDAvis.enable_notebook()
vis = pyLDAvis.lda_model.prepare(lda_model, doc_term_matrix, vectorizer)
pyLDAvis.display(vis)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el5511341008971611525446741353" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el5511341008971611525446741353_data = {"mdsDat": {"x": [-0.20410189212315305, -0.12908628993945243, 0.2279970168810233, -0.21258288633492756, 0.31777405151650917], "y": [0.06550408070992805, -0.29395416508584915, -0.04377504485341764, 0.1906290672419148, 0.08159606198742396], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [21.991779966998504, 20.909635572118752, 19.99897069230682, 18.771745974106192, 18.327867794469725]}, "tinfo": {"Term": ["\uc219\ubc15", "\ubcd1\uc6d0", "\uc608\uc57d", "\uc2dc\uac04", "\ud638\ud154", "\uc9c4\ub8cc", "\ud655\uc778", "\uc8fc\ucc28", "\uc219\uc18c", "\uc9c1\uc6d0", "\uc694\uae08", "\uc5bc\ub9c8", "\uac04\ud638\uc0ac", "\ud638\ucd9c", "\uc2dc\uc124", "\uc5b8\uc81c", "\ub0b4\uacfc", "\uac04\ubcd1\uc778", "\uccb4\ud06c\uc544\uc6c3", "\ucc28\ube44", "\uc5ec\uae30", "\uccb4\ud06c", "\ubc84\uc2a4", "\uc704\uce58", "\uc9c0\uae08", "\uad00\uad11\uc9c0", "\uadfc\ucc98", "\uc5b4\ub514", "\ubc30\ucc28", "\uc9c0\ub3c4", "\ubc84\uc2a4", "\ubc30\ucc28", "\ucde8\uc18c", "\uc77c\uc815", "\uac04\uaca9", "\uc624\uc804", "\ub300\ud559", "\uc815\ud615\uc678\uacfc", "\uc601\uc5c5", "\uc0bc\uc131", "\uc2dc\ub85c", "\uacf5\uac04", "\uc11c\uc6b8\uc5ed", "\ubcf4\uc548", "\uc758\ub8cc", "\uba74\ud68c", "\ubaa8\ub4e0", "\uc11c\uc6b8", "\uc0ad\uc81c", "\uc74c\uc2
"\ud55c\ud654", "\uc704\uce58", "\uc774\uc81c", "\uc2e4\ub85c", "\uc5b4\ub514", "\uc9c0\ub3c4", "\ud658\uc790", "\uac00\uc57c", "\uacb0\uc81c", "\uc218\uc601\uc7a5", "\ubcd1\uc6d0", "\uc8fc\ucc28", "\uce74\ud398", "\uc694\uae08", "\uc2dc\uc124", "\ube44\uc6a9", "\uc8fc\ucc28\uc7a5", "\uc5d8\ub9ac\ubca0\uc774\ud130", "\ucc28\ube44", "\uc624\ub77c", "\ubb34\uacfc", "\uc548\ub0b4", "\ud3b8\uc758\uc810", "\uc5ec\uae30", "\uc0c1\uc138", "\uc774\uc6a9", "\uc8fc\ubcc0", "\uc815\ubcf4", "\ub0b4\uacfc", "\uc2dd\ub2f9", "\uc120\uc0dd\ub2d8", "\uc774\uc775", "\uad50\uc218", "\uc758\uc0ac", "\uc57d\ua ...

# %%
# 5. 토픽별 주요 단어 출력
def print_topics(model, vectorizer, top_n=10):
    for idx, topic in enumerate(model.components_):
        print(f"Topic {idx + 1}:")
        print([(vectorizer.get_feature_names_out()[i], topic[i])
                for i in topic.argsort()[:-top_n - 1:-1]])

print_topics(lda_model, vectorizer)
# Out:
# Topic 1:
# [('숙박', 12942.801135572674), ('예약', 11143.994855995483), ('호텔', 7744.190051401727), ('체크아웃', 3593.1967177774254), ('근처', 3577.504262233741), ('시설', 3149.609266963746), ('확인', 2955.5603206214064), ('변경', 2336.1740381339864), ('주변', 1941.5909296538034), ('공항', 1902.7272630154498)]
# Topic 2:
# [('병원', 10518.377480684196), ('주차', 4600.494352618592), ('어디', 3894.426371586869), ('요금', 3788.317966954504), ('시설', 3650.789109777444), ('간병인', 3498.195483201205), ('위치', 3211.616744610435), ('지도', 2757.0684620935695), ('정산', 2363.19801753539), ('차비', 2297.1941235647)]
# Topic 3:
# [('예약', 13902.248751878355), ('시간', 10446.644067961837), ('병원', 10323.804196688136), ('숙소', 5638.773344123371), ('진료', 4512.762723168427), ('버스', 3466.1957947339956), ('배차', 2731.1977385635105), ('취소', 2225.1993146485925), ('관계자', 1955.998983704592), ('가능', 1795.0006061083152)]
# Topic 4:
# [('확인', 5666.474937841727), ('진료', 4910.636489153653), ('언제', 3857.754120192817), ('예약', 3715.3557465716935), ('체크', 3618.7830121223565), ('시간', 3397.6403265784916), ('내과', 3301.1983125780816), ('오늘', 2279.0601545309382), ('식당', 2119.0922505231783), ('선생님', 1865.1981459678598)]
# Topic 5:
# [('직원', 4309.612005179383), ('간호사', 3875.4264229683226), ('얼마', 3814.1967172901755), ('호출', 3812.62047296056), ('주차', 3567.904116927619), ('여기', 3544.6986675944045), ('지금', 3210.7760268923857), ('차비', 3203.190528947254), ('관광지', 3151.002196475495), ('요금', 2994.080246094103)]
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# #중복 제거 값 LDA 분석

# %%
# 중복 제거
df_clean = df.drop_duplicates(subset=["대화"])
df_clean.reset_index(drop=True, inplace=True)
df_clean.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                       대화    성별    연령대        지역    사투리 녹음환경 소음환경  \
# 0  나 열 시에는 체크인할 수 있는 거야?  Male  20~29  서울/인천/경기  경기/서울  사무실  사무실
# 1            이거 어떻게 퇴실해?  Male  20~29  서울/인천/경기  경기/서울  사무실  사무실
# 2     주차 요금 나온 거 다 보여 줘.  Male  20~29  서울/인천/경기  경기/서울  사무실  사무실
# 3           주차비를 결제해 주지.  Male  20~29  서울/인천/경기  경기/서울  사무실  사무실
# 4         아무나 간병인 불러 줄래?  Male  20~29  서울/인천/경기  경기/서울  사무실  사무실
#
#                                파일이름 preprocessed
# 0  CE0271-1001-01-02-LTM-M-04-A.wav   나 열 시 체크 수
# 1  CE0271-1002-01-02-LTM-M-04-A.wav          거 퇴
# 2  CE0271-1003-01-02-LTM-M-04-A.wav      주차 요금 거
# 3  CE0271-1004-01-02-LTM-M-04-A.wav     차비 결제 주지
# 4  CE0271-1005-01-02-LTM-M-04-A.wav    아무나 간병인 줄

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4988 entries, 0 to 4987
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   대화            4988 non-null   object
#  1   성별            4988 non-null   object
#  2   연령대           4988 non-null   object
#  3   지역            4988 non-null   object
#  4   사투리           4988 non-null   object
#  5   녹음환경          4988 non-null   object
#  6   소음환경          4988 non-null   object
#  7   파일이름          4988 non-null   object
#  8   preprocessed  4988 non-null   object
# dtypes: object(9)
# memory usage: 350.8+ KB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pandas as pd
import numpy as np
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import pyLDAvis
import pyLDAvis.lda_model

# 1. 텍스트 전처리
def preprocess_text(text):
    if pd.isna(text):
        return ""
    okt = Okt()
    tokens = okt.nouns(str(text))  # 문자열로 변환
    return ' '.join(tokens)

# NaN 값 확인
print("전처리 전 NaN 값의 수:", df_clean['대화'].isna().sum())

# 전처리 적용
df_clean['preprocessed'] = df_clean['대화'].apply(preprocess_text)

# 전처리 후 빈 문자열 확인
print("전처리 후 빈 문자열의 수:", (df_clean['preprocessed'] == '').sum())

# 빈 문자열 제거
df_clean = df_clean[df_clean['preprocessed'] != '']

# 2. 단어 벡터화
vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
doc_term_matrix = vectorizer.fit_transform(df_clean['preprocessed'])

# 3. LDA 모델 학습
lda_model = LatentDirichletAllocation(n_components=5, random_state=42)
lda_output = lda_model.fit_transform(doc_term_matrix)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 전처리 전 NaN 값의 수: 0
# <ipython-input-14-3bd4136b0f94>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['preprocessed'] = df_clean['대화'].apply(preprocess_text)
# 전처리 후 빈 문자열의 수: 0

# %%
# 4. 결과 시각화
pyLDAvis.enable_notebook()
vis = pyLDAvis.lda_model.prepare(lda_model, doc_term_matrix, vectorizer)
pyLDAvis.display(vis)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el5511341008971637282649050832" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el5511341008971637282649050832_data = {"mdsDat": {"x": [-0.2518941168013338, 0.10622063726751088, -0.15885365514890196, 0.06601941903979529, 0.23850771564292972], "y": [0.15771908240971977, 0.23270416167065178, -0.23302146523393033, -0.09006844032343496, -0.06733333852300635], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [29.00939713668581, 19.820748589168435, 18.909426380640586, 16.293366220544193, 15.96706167296098]}, "tinfo": {"Term": ["\uc608\uc57d", "\uc8fc\ucc28", "\uc2dc\uc124", "\uc694\uae08", "\uc9c4\ub8cc", "\uc548\ub0b4", "\ucc28\ube44", "\ud638\ud154", "\uac04\ubcd1\uc778", "\uc5bc\ub9c8", "\uc219\uc18c", "\uccb4\ud06c\uc544\uc6c3", "\uc2dc\uac04", "\ubc84\uc2a4", "\uadfc\ucc98", "\uc9c0\ub3c4", "\uad00\uad11\uc9c0", "\uccb4\ud06c", "\uc815\ubcf4", "\ubc30\ucc28", "\uc8fc\ubcc0", "\uc219\ubc15", "\uc9c1\uc6d0", "\uac04\ud638\uc0ac", "\uc5b4\ub514", "\uc9c0\uae08", "\ubcc0\uac
dc\uac04", "\ubcd1\uc6d0", "\ubcd1\uc2e4", "\uc2dc\uac04\ud45c", "\uc5b4\ub514", "\uc5b8\uc81c", "\ubd80\ud0c1", "\uc5ec\uae30", "\uac80\uc0c9", "\uc2dc\uc124", "\uccb4\ud06c\uc544\uc6c3", "\uc815\ubcf4", "\uc774\uc6a9", "\ud3b8\uc758\uc810", "\ub9cc\ub450", "\uc0c1\uc138", "\ub300\ud574", "\ube44\uad50", "\ud3b8\uc758", "\ube44\ube44\uace0", "\ub9db\uc9d1", "\uc11c\uc6b8\uc5ed", "\uace0\ud5a5", "\uc720\uc0ac", "\ub300\ud55c", "\uc2dc\uc57c", "\ub098\uac00\uc57c", "\uc0c1\ud0dc", "\uac00\uac8c", "\uc804\uccb4", "\ubc31\uc77c", "\ub180\uc774", "\ubc29\uc774", "\ubcf4\uc548", "\uc815\ub958\uc7a5", "\uc7a5\uae30\uc774\uc2dd", "\uc8fc\uc704", "\ubcd1\ub3d9", "\uc81c\uacf5", "\ucd94\uac00", "\uc0c1\ud488", "\uac04\ud638\uc0ac", "\uc219\uc18c", "\uacf5\ud56d", "\uac00\uaca9", "\uc704\uce58", "\uac80\uc0c9", "\uc219\ubc15", "\uc8fc\ucc28\uc7a5", "\ub9c8\ud2b8", "\ud638\ucd9c", "\ubcd1\uc6d0", "\uc5b4\ub514", "\ud655\uc778", "\uc8fc\ubcc0", "\uc124\uba85", "\ ...

# %%
# 5. 토픽별 주요 단어 출력
def print_topics(model, vectorizer, top_n=10):
    feature_names = vectorizer.get_feature_names_out()
    for idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[:-top_n - 1:-1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]
        print(f"Topic {idx + 1}:")
        for feat, weight in zip(top_features, weights):
            print(f"{feat}: {weight:.4f}")
        print()

print_topics(lda_model, vectorizer)
# Out:
# Topic 1:
# 예약: 1085.1876
# 진료: 352.1987
# 시간: 345.4846
# 병원: 271.6362
# 숙박: 215.7451
# 확인: 172.3811
# 언제: 159.7840
# 변경: 138.1959
# 내과: 124.1964
# 오늘: 122.1936
#
# Topic 2:
# 주차: 318.1987
# 요금: 277.1833
# 차비: 194.1991
# 얼마: 165.1975
# 체크: 148.7049
# 지금: 118.5324
# 확인: 117.4245
# 직원: 112.6121
# 숙박: 109.9337
# 병원: 77.2141
#
# Topic 3:
# 병원: 224.4602
# 간병인: 143.1981
# 지도: 124.1939
# 어디: 106.8055
# 여기: 94.2582
# 관계자: 81.1980
# 달라: 80.0607
# 식당: 77.1965
# 취소: 70.1529
# 날짜: 69.1926
#
# Topic 4:
# 안내: 226.8623
# 호텔: 226.2687
# 버스: 150.3703
# 근처: 146.6166
# 시간: 139.6048
# 주변: 130.9574
# 관광지: 126.1980
# 배차: 116.1992
# 숙소: 100.3162
# 병원: 99.0572
#
# Topic 5:
# 시설: 238.1970
# 숙박: 142.3751
# 체크아웃: 135.1972
# 숙소: 129.0789
# 병원: 109.6322
# 정보: 106.1962
# 간호사: 94.2823
# 이용: 77.1923
# 위치: 58.5523
# 상품: 58.3517
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
