# %%
import numpy as np
import pandas as pd

# %%
path="/content/drive/MyDrive/mulcam_bigdata/3조 : 최종 프로젝트/공용/AI명령어 데이터/명령어 음성(노인남여)/AI비서 데이터_50대_training.csv"

# %%
pd.read_csv(path)
# Out:
#                             대화      성별    연령대           지역 사투리 녹음환경 소음환경  \
# 0             보고 있는 영상 정지시켜 줘.  Female  30~39     서울/인천/경기  전라   가정   가정
# 1               다음 주까지 날씨가 어때?  Female  30~39     서울/인천/경기  전라   가정   가정
# 2                  나 대신 점등해 줘.  Female  30~39     서울/인천/경기  전라   가정   가정
# 3            이번 주 대체로 흐린지 궁금해.  Female  30~39     서울/인천/경기  전라   가정   가정
# 4              지금 당장 취침 등 꺼 줘.  Female  30~39     서울/인천/경기  전라   가정   가정
# ...                        ...     ...    ...          ...  ..  ...  ...
# 630183         이후 칠일간 날씨 어떨거래?    Male  40~49  부산/대구/울산/경상  경상   가정   가정
# 630184        오디오북 오 분 뒤에 꺼 줘.    Male  40~49  부산/대구/울산/경상  경상   가정   가정
# 630185         일요일의 강수량의 퍼센트는?    Male  40~49  부산/대구/울산/경상  경상   가정   가정
# 630186  지금 퇴근하니까 보일러 온도 올려 줄래?    Male  40~49  부산/대구/울산/경상  경상   가정   가정
# 630187      오디오북 몇시간 남았는지 부탁해.    Male  40~49  부산/대구/울산/경상  경상   가정   가정
#
#                                             파일이름
# 0       script1_g_0249-6001-01-01-KCY-F-05-A.wav
# 1       script1_g_0249-6002-01-01-KCY-F-05-A.wav
# 2       script1_g_0249-6003-01-01-KCY-F-05-A.wav
# 3       script1_g_0249-6004-01-01-KCY-F-05-A.wav
# 4       script1_g_0249-6005-01-01-KCY-F-05-A.wav
# ...                                          ...
# 630183  script1_i_0350-8996-01-01-PSH-M-06-D.wav
# 630184  script1_i_0350-8997-01-01-PSH-M-06-D.wav
# 630185  script1_i_0350-8998-01-01-PSH-M-06-D.wav
# 630186  script1_i_0350-8999-01-01-PSH-M-06-D.wav
# 630187  script1_i_0350-9000-01-01-PSH-M-06-D.wav
#
# [630188 rows x 8 columns]

# %%
raw = pd.read_csv(path)
raw.head()
# Out:
#                   대화      성별    연령대        지역 사투리 녹음환경 소음환경  \
# 0   보고 있는 영상 정지시켜 줘.  Female  30~39  서울/인천/경기  전라   가정   가정
# 1     다음 주까지 날씨가 어때?  Female  30~39  서울/인천/경기  전라   가정   가정
# 2        나 대신 점등해 줘.  Female  30~39  서울/인천/경기  전라   가정   가정
# 3  이번 주 대체로 흐린지 궁금해.  Female  30~39  서울/인천/경기  전라   가정   가정
# 4    지금 당장 취침 등 꺼 줘.  Female  30~39  서울/인천/경기  전라   가정   가정
#
#                                        파일이름
# 0  script1_g_0249-6001-01-01-KCY-F-05-A.wav
# 1  script1_g_0249-6002-01-01-KCY-F-05-A.wav
# 2  script1_g_0249-6003-01-01-KCY-F-05-A.wav
# 3  script1_g_0249-6004-01-01-KCY-F-05-A.wav
# 4  script1_g_0249-6005-01-01-KCY-F-05-A.wav

# %%
df = raw.copy()
df.head()
# Out:
#                   대화      성별    연령대        지역 사투리 녹음환경 소음환경  \
# 0   보고 있는 영상 정지시켜 줘.  Female  30~39  서울/인천/경기  전라   가정   가정
# 1     다음 주까지 날씨가 어때?  Female  30~39  서울/인천/경기  전라   가정   가정
# 2        나 대신 점등해 줘.  Female  30~39  서울/인천/경기  전라   가정   가정
# 3  이번 주 대체로 흐린지 궁금해.  Female  30~39  서울/인천/경기  전라   가정   가정
# 4    지금 당장 취침 등 꺼 줘.  Female  30~39  서울/인천/경기  전라   가정   가정
#
#                                        파일이름
# 0  script1_g_0249-6001-01-01-KCY-F-05-A.wav
# 1  script1_g_0249-6002-01-01-KCY-F-05-A.wav
# 2  script1_g_0249-6003-01-01-KCY-F-05-A.wav
# 3  script1_g_0249-6004-01-01-KCY-F-05-A.wav
# 4  script1_g_0249-6005-01-01-KCY-F-05-A.wav

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630188 entries, 0 to 630187
# Data columns (total 8 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   대화      630188 non-null  object
#  1   성별      630188 non-null  object
#  2   연령대     630188 non-null  object
#  3   지역      630188 non-null  object
#  4   사투리     630188 non-null  object
#  5   녹음환경    630188 non-null  object
#  6   소음환경    630188 non-null  object
#  7   파일이름    630188 non-null  object
# dtypes: object(8)
# memory usage: 38.5+ MB

# %% [markdown]
# #LDA 분석

# %%
# !pip install -q pandas numpy scikit-learn konlpy pyLDAvis
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 25.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 86.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 35.5 MB/s eta 0:00:00

# %%
import pandas as pd
import numpy as np
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import pyLDAvis.lda_model

# 1. 텍스트 전처리
def preprocess_text(text):
    okt = Okt()
    tokens = okt.nouns(text)  # 명사만 추출
    return ' '.join(tokens)

df['preprocessed'] = df['대화'].apply(preprocess_text)

# 2. 단어 벡터화
vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
doc_term_matrix = vectorizer.fit_transform(df['preprocessed'])

# 3. LDA 모델 학습
lda_model = LatentDirichletAllocation(n_components=5, random_state=42)
lda_output = lda_model.fit_transform(doc_term_matrix)

# %%
# 4. 결과 시각화
pyLDAvis.enable_notebook()
vis = pyLDAvis.lda_model.prepare(lda_model, doc_term_matrix, vectorizer)
pyLDAvis.display(vis)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4391345851626525128902136680" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el4391345851626525128902136680_data = {"mdsDat": {"x": [0.13785556474970023, -0.3293310368664909, 0.14975626310117557, -0.17963108932829588, 0.22135029834391098], "y": [0.11685264674672718, 0.22858137580753482, -0.05304438028316598, -0.3287793914269405, 0.036389749155844545], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [21.544066418890267, 21.135882889517518, 20.647656461687134, 18.895200259713025, 17.777193970192048]}, "tinfo": {"Term": ["\ucee4\ud53c", "\ub0b4\uc77c", "\uc0ac\uace0", "\uc624\ub298", "\ubaa8\ub4dc", "\ube14\ub77c\uc778\ub4dc", "\ub274\uc2a4", "\ud604\uc7ac", "\uc0c1\ud669", "\uad50\ud1b5", "\uc9c0\uae08", "\uc8fc\ub9d0", "\uba38\uc2e0", "\ucde8\uce68", "\uacbd\uae30", "\uc990\uaca8\ucc3e\uae30", "\ub0a0\uc528", "\uc624\ub514\uc624\ubd81", "\ud1a0\uc2a4\ud130", "\ud658\uc728", "\uc808\uc57d", "\ud50c\ub808\uc774", "\uc5d0\ub108\uc9c0", "\uc77c\uc815", "\ub9ac\uc2a4\ud2b8", "\uc124\uc815", "\uacf5\uae30\uccad\uc815\uae30", "\uacbd\ub85c", "\uc8fc\uc694", "\ub178\ub798", "\ub274\uc2a4", "\ud50c\ub808\uc774", "\ub9ac\uc2a4\ud2b8", "\ud658\uc728", "\uc8fc\uc694", "\uc5b8\uc81c", "\uae08\uc735", "\uc
d80\ud0c1", "\ud2f0\ube44", "\ud655\uc778", "\uc624\ub514\uc624\ubd81", "\uc804\ubd80", "\ub300\ud574", "\uc774\ubc88", "\uc8fc\uac00", "\uc0c1\ud0dc", "\uccb4\ud06c", "\uc815\ubcf4", "\ucee4\ud53c", "\uba38\uc2e0", "\ud1a0\uc2a4\ud130", "\ucf58\ud150\uce20", "\ud2f0\ube0c\uc774", "\uacf5\uae30\uccad\uc815\uae30", "\uc804\ub4f1", "\uc791\ub3d9", "\uc815\uc9c0", "\ubbf8\ub9ac", "\uc624\ud504", "\ub3d9\uc791", "\ud1f4\uadfc", "\uc2a4\ud1b1", "\uc544\uba54\ub9ac\uce74\ub178", "\uc6b4\uc804", "\uc774\ud6c4", "\ucd94\ucd9c", "\uac00\uc5f4", "\ub3d9\ud574", "\ud30c\uc6cc", "\uc911\uacc4", "\uc218\uba74", "\ubc84\ud2bc", "\ud0c0\uc774\uba38", "\uc138\ucc99", "\uc5ec\ub35f", "\uc5b4\ub518", "\ubaa9\uc801\uc9c0", "\ud55c\uc794", "\u ...

# %%
# 5. 토픽별 주요 단어 출력
def print_topics(model, vectorizer, top_n=10):
    for idx, topic in enumerate(model.components_):
        print(f"Topic {idx + 1}:")
        print([(vectorizer.get_feature_names_out()[i], topic[i])
                for i in topic.argsort()[:-top_n - 1:-1]])

print_topics(lda_model, vectorizer)
# Out:
# Topic 1:
# [('내일', 30478.61014001467), ('사고', 24943.054421589448), ('블라인드', 23561.199308875883), ('날씨', 18083.68421493583), ('즐겨찾기', 16307.415564899844), ('노래', 10954.19849437439), ('예보', 9774.197983128372), ('확인', 9633.95064981274), ('이번', 8295.125199546941), ('다음', 5476.042125749227)]
# Topic 2:
# [('모드', 26854.190152976305), ('취침', 19526.19821926702), ('경기', 18953.670027943048), ('절약', 16430.19939531402), ('에너지', 14901.199401983118), ('일정', 14693.020474690591), ('온도', 13997.410819002933), ('오디오북', 13607.47586336041), ('설정', 13562.831863431724), ('목소리', 11427.199129260202)]
# Topic 3:
# [('오늘', 32418.032891669238), ('뉴스', 26330.19965158547), ('환율', 16703.986375414104), ('플레이', 15467.199216114699), ('리스트', 14706.199252143548), ('확인', 13296.79333841566), ('주요', 13202.199772032638), ('주가', 12116.93743129753), ('지금', 10748.488913518384), ('언제', 10170.194261938903)]
# Topic 4:
# [('커피', 34111.19930493216), ('오디오북', 21126.513671295474), ('머신', 18075.199666261316), ('토스터', 15239.199350022483), ('시간', 13380.993375626014), ('공기청정기', 12356.266779465119), ('콘텐츠', 11202.199282825857), ('티브이', 10962.198692844022), ('지금', 8301.558311434046), ('재생', 7396.1423205412575)]
# Topic 5:
# [('지금', 30839.43390599243), ('현재', 23786.842240073936), ('상황', 20921.198671101636), ('교통', 20435.19896392791), ('주말', 19875.355447531085), ('날씨', 17693.637712455926), ('경로', 13024.197673994791), ('속도', 12046.192617694976), ('오디오북', 11258.608937696428), ('추천', 10690.19817466848)]
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# #중복 제거 값 LDA 분석

# %%
# 중복 제거
df_clean = df.drop_duplicates(subset=["대화"])
df_clean.reset_index(drop=True, inplace=True)
df_clean.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                   대화      성별    연령대        지역 사투리 녹음환경 소음환경  \
# 0   보고 있는 영상 정지시켜 줘.  Female  30~39  서울/인천/경기  전라   가정   가정
# 1     다음 주까지 날씨가 어때?  Female  30~39  서울/인천/경기  전라   가정   가정
# 2        나 대신 점등해 줘.  Female  30~39  서울/인천/경기  전라   가정   가정
# 3  이번 주 대체로 흐린지 궁금해.  Female  30~39  서울/인천/경기  전라   가정   가정
# 4    지금 당장 취침 등 꺼 줘.  Female  30~39  서울/인천/경기  전라   가정   가정
#
#                                        파일이름 preprocessed
# 0  script1_g_0249-6001-01-01-KCY-F-05-A.wav     보고 영상 정지
# 1  script1_g_0249-6002-01-01-KCY-F-05-A.wav      다음 주 날씨
# 2  script1_g_0249-6003-01-01-KCY-F-05-A.wav      나 대신 점등
# 3  script1_g_0249-6004-01-01-KCY-F-05-A.wav     이번 주 대체로
# 4  script1_g_0249-6005-01-01-KCY-F-05-A.wav   지금 당장 취침 등

# %%
df_clean.info()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13670 entries, 0 to 13669
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   대화            13670 non-null  object
#  1   성별            13670 non-null  object
#  2   연령대           13670 non-null  object
#  3   지역            13670 non-null  object
#  4   사투리           13670 non-null  object
#  5   녹음환경          13670 non-null  object
#  6   소음환경          13670 non-null  object
#  7   파일이름          13670 non-null  object
#  8   preprocessed  13670 non-null  object
# dtypes: object(9)
# memory usage: 961.3+ KB

# %%
import pandas as pd
import numpy as np
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import pyLDAvis
import pyLDAvis.lda_model

# 1. 텍스트 전처리
def preprocess_text(text):
    if pd.isna(text):
        return ""
    okt = Okt()
    tokens = okt.nouns(str(text))  # 문자열로 변환
    return ' '.join(tokens)

# NaN 값 확인
print("전처리 전 NaN 값의 수:", df_clean['대화'].isna().sum())

# 전처리 적용
df_clean['preprocessed'] = df_clean['대화'].apply(preprocess_text)

# 전처리 후 빈 문자열 확인
print("전처리 후 빈 문자열의 수:", (df_clean['preprocessed'] == '').sum())

# 빈 문자열 제거
df_clean = df_clean[df_clean['preprocessed'] != '']

# 2. 단어 벡터화
vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
doc_term_matrix = vectorizer.fit_transform(df_clean['preprocessed'])

# 3. LDA 모델 학습
lda_model = LatentDirichletAllocation(n_components=5, random_state=42)
lda_output = lda_model.fit_transform(doc_term_matrix)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 전처리 전 NaN 값의 수: 0
# <ipython-input-13-3bd4136b0f94>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['preprocessed'] = df_clean['대화'].apply(preprocess_text)
# 전처리 후 빈 문자열의 수: 11

# %%
# 4. 결과 시각화
pyLDAvis.enable_notebook()
vis = pyLDAvis.lda_model.prepare(lda_model, doc_term_matrix, vectorizer)
pyLDAvis.display(vis)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4391345851626532961493705128" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el4391345851626532961493705128_data = {"mdsDat": {"x": [0.2195519240588358, -0.103424920598814, 0.24028410448603132, -0.2542173514747996, -0.10219375647125327], "y": [0.03552266533579812, -0.18485130942467015, 0.09224950089860622, 0.2844970096577982, -0.22741786646753223], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [24.16320930262145, 20.024556639494264, 19.306564164876942, 18.41853066565814, 18.087139227349205]}, "tinfo": {"Term": ["\uc624\ub514\uc624\ubd81", "\ucee4\ud53c", "\ub274\uc2a4", "\uc624\ub298", "\uc774\ubc88", "\uc0ac\uace0", "\ucde8\uce68", "\ub0b4\uc77c", "\ube14\ub77c\uc778\ub4dc", "\uba38\uc2e0", "\ud658\uc728", "\ud604\uc7ac", "\ud1a0\uc2a4\ud130", "\ubaa8\ub4dc", "\uc624\ub514\uc624", "\uc990\uaca8\ucc3e\uae30", "\uc8fc\uc694", "\uc9c0\uae08", "\uad50\ud1b5", "\
uc2a4\ud504\ub808\uc18c", "\uc7a5\ub9c8", "\ucd94\uac00", "\uad50\ucc28", "\ub2e4\uc2dc", "\uc774\ub984", "\uae30\uc900", "\ubbf8\uc138", "\uc6b0\ud68c", "\uc81c\uc678", "\ub9ac\uadf8", "\ucc28\uc774", "\ud504\ub808\uc774", "\uc601\uc0c1", "\ub3c4\ub85c\ub85c", "\ub54c\ubb38", "\uc74c\uc545", "\uc608\ubcf4", "\ub3d9\uc548", "\uc8fc\uc2dd", "\ubaa8\ub450", "\ud2f0\ube0c\uc774", "\ubcf4\uace0", "\uc8fc\ub9d0", "\uc815\ubcf4", "\ud655\uc778", "\uad6c\uac04", "\ub3c4\ucc29", "\ub0a0\uc528", "\uc9c0\uae08", "\uc7ac\uc0dd", "\ub2ec\ub7ec", "\uacbd\uae30", "\uc77c\uc815", "\ubd80\ud0c1", "\ud2f0\ube44", "\ucee4\ud53c", "\uba38\uc2e0", "\ud1a0\uc2a4\ud130", "\ud1a0\uc2a4\ud2b8", "\uc791\ub3d9", "\uc544\uce68", "\uc804\ub4f1", "\uacf5\uae30", "\uc2dc\uc791", "\uc804\ubd80", "\ube14\ub77c\uc778\ub4dc", "\ube0c\ub77c", "\uc624\ud504", "\ud587\ube5b", "\ub3d9\uc791", "\ubbf8\ub9ac", "\uc704\uce58", "\uadfc\ucc98", "\uc9c0\uc810", "\uace0\uc18d\ub3c4\ub85c", "\uc544\uba54\ub9ac\uce74\ub178", "\uc2a4\uc704\uce58", "\uc120\ud0dd", "\uc790\uc8fc", "\uac00\uc5f4",  ...

# %%
# 5. 토픽별 주요 단어 출력
def print_topics(model, vectorizer, top_n=10):
    feature_names = vectorizer.get_feature_names_out()
    for idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[:-top_n - 1:-1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]
        print(f"Topic {idx + 1}:")
        for feat, weight in zip(top_features, weights):
            print(f"{feat}: {weight:.4f}")
        print()

print_topics(lda_model, vectorizer)
# Out:
# Topic 1:
# 오디오북: 902.1988
# 취침: 488.1990
# 모드: 361.9239
# 오디오: 353.1990
# 설정: 321.1957
# 콘텐츠: 273.1994
# 속도: 259.1996
# 목소리: 237.1994
# 지금: 219.3665
# 시간: 217.4650
#
# Topic 2:
# 지금: 625.5641
# 내일: 570.1961
# 날씨: 504.0017
# 현재: 442.1873
# 교통: 377.1980
# 상황: 367.1978
# 확인: 350.3041
# 온도: 343.8478
# 보일러: 275.5683
# 경기: 259.1533
#
# Topic 3:
# 이번: 564.1243
# 환율: 375.6532
# 리스트: 289.1992
# 경로: 281.1981
# 플레이: 279.1995
# 추천: 214.1980
# 확인: 209.9292
# 언제: 194.4495
# 지금: 184.6649
# 날씨: 164.1757
#
# Topic 4:
# 오늘: 645.8630
# 뉴스: 626.1991
# 즐겨찾기: 307.4804
# 주요: 291.1994
# 노래: 258.1937
# 얼마나: 251.0747
# 모드: 212.4750
# 절약: 185.3739
# 에너지: 157.1931
# 날씨: 145.4220
#
# Topic 5:
# 커피: 675.1984
# 사고: 552.2667
# 블라인드: 382.8055
# 머신: 373.1990
# 토스터: 348.1990
# 시간: 255.9304
# 공기청정기: 196.5392
# 티비: 195.5037
# 토스트: 143.1987
# 확인: 126.3046
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
